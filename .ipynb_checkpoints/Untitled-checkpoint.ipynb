# %%
import numpy as np

# %%
delta_x = np.array([1, 0, -1, 0])
delta_y = np.array([0, 1, 0, -1])
np.arctan2(delta_x, delta_y) - np.pi /2 + np.pi
# Out:
#   File "<ipython-input-7-a1ea701e9f3f>", line 3
#     np.arctan2(delta_x, delta_y) - np.pi /2 + np=pi
#     ^
# SyntaxError: cannot assign to operator

# %%
np.pi * 2
# Out:
# 6.283185307179586
