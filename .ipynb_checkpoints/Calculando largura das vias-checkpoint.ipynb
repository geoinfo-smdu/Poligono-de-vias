# %% [markdown]
# # Calculando Largura de Vias
#
# Neste Jupyter Notebook vamos validar a POC calculando a largura de vias para todo um distrito que possui Polígono de vias desenhado

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams['figure.figsize'] = (40, 30)

# %%
# df_qf = gpd.read_file(f'gis/SIRGAS_SHP_quadraMDSF.shp')
# df_qv = gpd.read_file(f'gis/SIRGAS_SHP_quadraviariaed_polygon.shp')
df_l = gpd.read_file(f'gis/SIRGAS_SHP_logradouronbl.shp')

# %%
df_s = gpd.read_file(f'gis/SIRGAS_SHP_distrito_polygon.shp')
df_s = df_s[df_s['ds_nome'] == 'VILA MARIANA']

# %%
# df_pvias = gpd.read_file("./resultado/poligono_de_vias.gpkg", layer='90 - poligono de vias de vila mariana')
df_pvias = gpd.read_file('resultado/90 - poligono de vias de vila mariana.gpkg')

# %%
df_pvias.plot()

# %% [markdown]
# ## Limitando as vias que intersectam os poligonos

# %%
df_s_sindex = df_s.sindex
df_l_sindex = df_l.sindex

# %%
# Get the bounding box coordinates of the Polygon as a list
bounds = list(df_s.bounds.values[0])

# Get the indices of the Points that are likely to be inside the bounding box of the given Polygon
l_candidate_idx = list(df_l_sindex.intersection(bounds))
l_candidates = df_l.loc[l_candidate_idx]

# %%
df_l = gpd.clip(l_candidates, df_s)

# %% [markdown]
# ## Criando pontos regulares sobre as linhas da via

# %%
import math
from shapely.geometry import MultiPoint

dist = 12.00

points = df_l.apply(lambda x: MultiPoint([x.geometry.interpolate(((i)*dist)+dist/2+(x.geometry.length%dist)/2) 
                                              for i in range(math.floor(x.geometry.length/dist))]), 
                        axis=1)

df_points = gpd.GeoDataFrame(geometry=points)

# %% [markdown]
# ## Quebrando a geometria do polígono de vias

# %%
from shapely.geometry import Point, MultiLineString, LineString, MultiPoint
from shapely.ops import substring, nearest_points, split, linemerge

# %%
def ponto_maior_borda(g):
    linhas_de_borda = split(MultiPoint(g.coords[:]).convex_hull.boundary, MultiPoint(g.coords[:]))
    maior_borda = max(linhas_de_borda, key=(lambda x: x.length))
    ponto_maior_borda = Point(maior_borda.coords[0])
    return ponto_maior_borda

df_pvias['geometry_ponto_inicial'] = gpd.GeoDataFrame(geometry=df_pvias.exterior.apply(lambda x: ponto_maior_borda(x)))

# %%
df_pvias
# Out:
#                                                geometry  \
# 0     POLYGON Z ((335240.868 7391047.004 0.000, 3352...
# 1     POLYGON Z ((335207.390 7390994.550 0.000, 3352...
# 2     POLYGON Z ((335146.804 7390957.456 0.000, 3351...
# 3     POLYGON Z ((335005.505 7390915.742 0.000, 3349...
# 4     POLYGON Z ((334938.200 7390852.834 0.000, 3349...
# ...                                                 ...
# 2270  POLYGON Z ((334847.946 7390752.223 0.000, 3348...
# 2271  POLYGON Z ((334844.203 7390754.734 0.000, 3348...
# 2272  POLYGON Z ((334846.486 7390761.526 0.000, 3348...
# 2273  POLYGON Z ((334846.486 7390761.526 0.000, 3348...
# 2274  POLYGON Z ((334846.436 7390761.248 0.000, 3348...
#
#                                geometry_ponto_inicial
# 0     POINT Z (335198.3177456815 7391003.681207987 0)
# 1     POINT Z (335142.4317388504 7390970.495225214 0)
557 7391309.04168 0, 331759.89479 7391309.15475 0, 331760.62737 7391309.24521 0, 331767.21354 7391310.27696 0, 331770.14073 7391310.73551 0, 331771.60458 7391310.96411 0, 331772.33316 7391311.10017 0, 331773.0537 7391311.27392 0, 331773.76423 7391311.48487 0, 331774.46284 7391311.73248 0, 331775.14764 7391312.01605 0, 331775.81676 7391312.33484 0, 331776.46841 7391312.68796 0, 331777.10082 7391313.07448 0, 331777.71228 7391313.49334 0, 331778.30112 7391313.94341 0, 331778.86577 7391314.42347 0, 331779.4047 7391314.93222 0, 331779.9586 7391315.42249 0, 331792.50932 7391325.79904 0, 331798.21419 7391330.51566 0, 331801.06663 7391332.87397 0, 331802.77809 7391334.28895 0, 331809.14349 7391339.3762 0, 331812.61701 7391342.14939 0, 331813.24741 7391342.6527 0, 331823.50785 7391351.07449 0, 331841.85751 7391365.53049 0, 331842.40308 7391366.04295 0, 331842.93489 7391366.57018 0, 331843.45252 7391367.11176 0, 331843.95555 7391367.66727 0, 331844.4436 7391368.23627 0, 331844.91627 7391368.8183 0, 331845.3732 7391369.41292 0, 331847.7745 7391372.83543 0, 331848.17695 7391373.46647 0, 331848.50766 7391374.13743 0, 331848.7557315062 7391374.821258883 0, 331855.4256033605 7391372.401574553 0, 331857.1568425485 7391370.262861943 0), (331748.39097 7391290.35441 0, 331765.34722 7391303.84338 0, 331760.45624 7391303.18118 0, 331759.53919 7391302.9144 0, 331758.94939 7391302.58888 0, 331751.20204 7391296.42924 0, 331750.73239 7391295.84641 0, 331750.51677 7391295.43041 0, 331748.39097 7391290.35441 0))
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# MULTILINESTRING Z ((334842.8250976639 7390747.642849949 0, 334842.4623687722 7390746.906634463 0, 334842.3517194489 7390746.79936963 0, 334842.2172519375 7390748.408707106 0, 334842.5843595772 7390748.826383054 0), (334842.9408222585 7390749.231947723 0, 334843.1748022389 7390749.498157956 0, 334843.2148013308 7390749.355410624 0))
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# MULTILINESTRING Z ((331576.6590911375 7391275.436976015 0, 331576.5225265065 7391275.350763296 0, 331576.6179635569 7391275.467478308 0), (331578.0463142535 7391276.845766682 0, 331580.7278328367 7391278.882752613 0, 331579.7510681023 7391277.388929016 0, 331578.2326390111 7391276.430350652 0))
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY
# LINESTRING EMPTY

# %%
df_pvias.plot()

# %%
df_point_to_border = gpd.sjoin(df_points[~df_points.is_empty].reset_index(drop=True).explode(), df_pvias, op='within')
# Out:
# <ipython-input-17-23df1b2b1296>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:31983
#
#   df_point_to_border = gpd.sjoin(df_points[~df_points.is_empty].reset_index(drop=True).explode(), df_pvias, op='within')

# %%
def calc_distancia(p):
    try:
        l_dist = LineString([nearest_points(p.geometry, p.geometry_bordas[0])[1], 
                             nearest_points(p.geometry, p.geometry_bordas[1])[1]])
        if p.geometry.distance(l_dist) < 1:
            return l_dist
    except: 
        print(p)
    
df_dists = gpd.GeoDataFrame(geometry=df_point_to_border.apply(lambda x: calc_distancia(x), axis=1))
# Out:
# geometry                      POINT (331846.1518153253 7391364.786404895)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 0), dtype: object
# geometry                      POINT (331836.8778325805 7391357.171075352)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 1), dtype: object
# geometry                      POINT (331827.6038498356 7391349.555745809)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 2), dtype: object
# geometry                      POINT (331818.3298670907 7391341.940416266)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 3), dtype: object
# geometry                      POINT (331809.0558843459 7391334.325086723)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 4), dtype: object
# geometry                       POINT (331799.7819016011 7391326.70975718)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 5), dtype: object
# geometry                      POINT (331790.5079188562 7391319.094427637)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 6), dtype: object
# geometry                      POINT (331781.2339361113 7391311.479098094)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 7), dtype: object
# geometry                      POINT (331771.9599533665 7391303.863768551)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 8), dtype: object
# geometry                      POINT (331762.6859706216 7391296.248439008)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 9), dtype: object
# geometry                      POINT (331753.4119878768 7391288.633109465)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 10), dtype: object
# geometry                      POINT (331744.1380051319 7391281.017779922)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 11), dtype: object
# geometry                      POINT (331734.8640223871 7391273.402450379)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 12), dtype: object
# geometry                      POINT (331725.4725667072 7391265.932572107)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 13), dtype: object
# geometry                      POINT (331716.0761413539 7391258.468847127)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 14), dtype: object
# geometry                      POINT (331706.6797160005 7391251.005122147)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 15), dtype: object
# geometry                      POINT (331697.2832906471 7391243.541397166)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 16), dtype: object
# geometry                      POINT (331687.8868652938 7391236.077672186)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 17), dtype: object
# geometry                      POINT (331678.4904399405 7391228.613947206)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 18), dtype: object
# geometry                      POINT (331669.0940145871 7391221.150222226)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 19), dtype: object
# geometry                      POINT (331659.6975892338 7391213.686497246)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 20), dtype: object
# geometry                      POINT (331650.3083709794 7391206.214009235)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 21), dtype: object
# geometry                       POINT (331641.171280671 7391198.434961691)
# index_right                                                          1758
# geometry_ponto_inicial    POINT Z (331857.7858251929 7391369.485838686 0)
# geometry_bordas                                                      None
# Name: (612, 22), dtype: object
# geometry                      POINT (334855.5827811869 7390886.535894168)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 0), dtype: object
# geometry                      POINT (334855.6419305152 7390874.536039946)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 1), dtype: object
# geometry                      POINT (334855.7010798436 7390862.536185724)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 2), dtype: object
# geometry                       POINT (334855.760229172 7390850.536331501)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 3), dtype: object
# geometry                      POINT (334855.8193785004 7390838.536477279)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 4), dtype: object
# geometry                      POINT (334854.9495558544 7390826.568140354)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 5), dtype: object
# geometry                      POINT (334854.0772388778 7390814.599888056)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 6), dtype: object
# geometry                      POINT (334853.2049219012 7390802.631635756)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 7), dtype: object
# geometry                      POINT (334853.1082596978 7390790.693529299)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (636, 8), dtype: object
# geometry                       POINT (334859.1333695619 7390787.13525843)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 0), dtype: object
# geometry                      POINT (334864.5897270398 7390797.819583479)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 1), dtype: object
# geometry                      POINT (334869.8155870235 7390808.621915979)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 2), dtype: object
# geometry                      POINT (334875.0414470072 7390819.424248478)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 3), dtype: object
# geometry                       POINT (334880.267306991 7390830.226580978)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 4), dtype: object
# geometry                      POINT (334885.5805046018 7390840.983877522)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 5), dtype: object
# geometry                        POINT (334891.3504854065 7390851.5056322)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 6), dtype: object
# geometry                      POINT (334897.1204662112 7390862.027386879)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 7), dtype: object
# geometry                      POINT (334902.8904470159 7390872.549141558)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 8), dtype: object
# geometry                      POINT (334909.4708355704 7390882.566992012)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 9), dtype: object
# geometry                       POINT (334916.3548188428 7390892.39607001)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 10), dtype: object
# geometry                      POINT (334923.3576449591 7390902.129221923)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 11), dtype: object
# geometry                      POINT (334931.5128569806 7390910.932205331)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 12), dtype: object
# geometry                      POINT (334939.6680690021 7390919.735188738)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 13), dtype: object
# geometry                      POINT (334947.8232810236 7390928.538172147)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 14), dtype: object
# geometry                      POINT (334957.6578899786 7390935.370090249)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 15), dtype: object
# geometry                      POINT (334967.6441128085 7390942.024063016)
# index_right                                                           321
# geometry_ponto_inicial    POINT Z (334978.6660895841 7390940.781242062 0)
# geometry_bordas                                                      None
# Name: (639, 16), dtype: object
# geometry                      POINT (332710.1703733864 7390863.562034045)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (940, 0), dtype: object
# geometry                      POINT (332721.6916306153 7390865.817401656)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (940, 1), dtype: object
# geometry                      POINT (332727.7601826449 7390875.816030156)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (940, 2), dtype: object
# geometry                      POINT (332725.5482168283 7390887.171366811)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (940, 3), dtype: object
# geometry                      POINT (332721.4107829526 7390882.054933385)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (941, 0), dtype: object
# geometry                      POINT (332718.5115749011 7390871.236236466)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (941, 1), dtype: object
# geometry                       POINT (332707.3606064299 7390870.77504943)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (941, 2), dtype: object
# geometry                       POINT (332703.6059942414 7390881.31366978)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (941, 3), dtype: object
# geometry                      POINT (332697.7508328598 7390875.618182375)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (942, 0), dtype: object
# geometry                      POINT (332699.8346180025 7390887.148895448)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (942, 1), dtype: object
# geometry                      POINT (332709.2413438865 7390893.983547012)
# index_right                                                          1245
# geometry_ponto_inicial    POINT Z (332712.1086002637 7390898.925785222 0)
# geometry_bordas                                                      None
# Name: (942, 2), dtype: object
# geometry                      POINT (333916.6300066202 7390016.009219535)
# index_right                                                           673
# geometry_ponto_inicial    POINT Z (333997.0922568243 7390023.618852334 0)
# geometry_bordas                                                      None
# Name: (1364, 0), dtype: object
# geometry                      POINT (333928.5168569188 7390017.642410442)
# index_right                                                           673
# geometry_ponto_inicial    POINT Z (333997.0922568243 7390023.618852334 0)
# geometry_bordas                                                      None
# Name: (1364, 1), dtype: object
# geometry                      POINT (333940.4171268603 7390019.186293637)
# index_right                                                           673
# geometry_ponto_inicial    POINT Z (333997.0922568243 7390023.618852334 0)
# geometry_bordas                                                      None
# Name: (1364, 2), dtype: object
# geometry                      POINT (333952.2604378794 7390021.094510973)
# index_right                                                           673
# geometry_ponto_inicial    POINT Z (333997.0922568243 7390023.618852334 0)
# geometry_bordas                                                      None
# Name: (1364, 3), dtype: object
# geometry                      POINT (333964.0640861965 7390023.256428272)
# index_right                                                           673
# geometry_ponto_inicial    POINT Z (333997.0922568243 7390023.618852334 0)
# geometry_bordas                                                      None
# Name: (1364, 4), dtype: object
# geometry                      POINT (333975.8677345136 7390025.418345571)
# index_right                                                           673
# geometry_ponto_inicial    POINT Z (333997.0922568243 7390023.618852334 0)
# geometry_bordas                                                      None
# Name: (1364, 5), dtype: object
# geometry                      POINT (333987.6637775651 7390027.621062153)
# index_right                                                           673
# geometry_ponto_inicial    POINT Z (333997.0922568243 7390023.618852334 0)
# geometry_bordas                                                      None
# Name: (1364, 6), dtype: object
# geometry                      POINT (331987.0423658335 7389887.085664425)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 0), dtype: object
# geometry                      POINT (331977.4250877008 7389894.262520134)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 1), dtype: object
# geometry                        POINT (331967.812917191 7389901.44626415)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 2), dtype: object
# geometry                      POINT (331958.3945115869 7389908.879192515)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 3), dtype: object
# geometry                      POINT (331949.2446638892 7389916.626029863)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 4), dtype: object
# geometry                      POINT (331944.3710426316 7389927.298048762)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 5), dtype: object
# geometry                      POINT (331942.9815210332 7389939.149913033)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 6), dtype: object
# geometry                      POINT (331946.3300138295 7389950.528453583)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 7), dtype: object
# geometry                      POINT (331951.6166965766 7389961.301149881)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 8), dtype: object
# geometry                      POINT (331956.9033793237 7389972.073846179)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 9), dtype: object
# geometry                      POINT (331962.1900620708 7389982.846542478)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 10), dtype: object
# geometry                       POINT (331967.476744818 7389993.619238776)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 11), dtype: object
# geometry                      POINT (331972.7634275651 7390004.391935074)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 12), dtype: object
# geometry                      POINT (331978.2007982563 7390015.088135411)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 13), dtype: object
# geometry                      POINT (331983.7769311602 7390025.713893823)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 14), dtype: object
# geometry                      POINT (331989.7883232635 7390036.092709493)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1466, 15), dtype: object
# geometry                      POINT (331985.5924047789 7390043.340938293)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 0), dtype: object
# geometry                      POINT (331974.2982876532 7390039.658182206)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 1), dtype: object
# geometry                       POINT (331966.2900862899 7390031.23085557)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 2), dtype: object
# geometry                       POINT (331960.171368136 7390020.908002857)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 3), dtype: object
# geometry                      POINT (331954.5858362807 7390010.289973452)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 4), dtype: object
# geometry                       POINT (331949.0854114665 7389999.62482803)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 5), dtype: object
# geometry                      POINT (331943.6372364208 7389988.933143754)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 6), dtype: object
# geometry                       POINT (331938.4416854918 7389978.11982725)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 7), dtype: object
# geometry                      POINT (331933.6191227276 7389967.131520357)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 8), dtype: object
# geometry                      POINT (331928.8235525816 7389956.131864889)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 9), dtype: object
# geometry                      POINT (331924.3455298734 7389944.998702147)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 10), dtype: object
# geometry                      POINT (331919.8675071652 7389933.865539405)
# index_right                                                          1606
# geometry_ponto_inicial    POINT Z (332002.0699552821 7390041.730506874 0)
# geometry_bordas                                                      None
# Name: (1468, 11), dtype: object

# %%
df_dists.plot()

# %%
df_point_to_border.plot()

# %%
# gdf_larguras = gpd.GeoDataFrame(geometry=df_point_to_border.geometry.reset_index(drop=True))

# %%
# gdf_larguras.plot()

# %%
df_dists.reset_index(drop=True, inplace=True)

# %%
df_dists['largura'] = df_dists.length

# %%
df_dists.crs = 'EPSG:31983'

# %%
df_largura_pontos = gpd.GeoDataFrame({'largura':df_dists.length}, geometry=df_dists.geometry.centroid)

# %%
larguras = gpd.sjoin(df_pvias, df_largura_pontos, how='left', op='intersects')['largura'].groupby(level=0).agg(['min', 'max', 'mean', 'std', 'count'] )

# %%
df_larguras = df_pvias.join(larguras).drop(columns=['geometry_ponto_inicial', 'geometry_bordas'])
# .to_file('resultado/90 - largura de vias Vila Mariana - com largura.gpkg', driver='GPKG')

# %%
df_larguras.rename(columns={"min": "largura_minima",
                            "max": "largura_maxima",
                            "mean": "largura_media",
                            "std": "largura_desvio_padrao",
                            "count": "largura_contagem_amostras"},
                  inplace=True)

# %% [markdown]
# ## Relacionando ao terreno

# %%
from rasterstats import zonal_stats

# %%
raster_stats = zonal_stats(vectors=df_larguras['geometry'], 
                           raster='/media/fernando/0dcfe7e0-23bd-4899-9552-3722ef65582e/MDT_SPTOTAL/SP_MDT_las_5m.tif')

# %%
# df_larguras = df_larguras.join(pd.DataFrame(raster_stats))

# %%
df_larguras.rename(columns={"min": "cota_minima",
                            "max": "cota_maxima",
                            "mean": "cota_media",
                            "count": "cota_contagem_amostras"},
                  inplace=True)

# %%
df_larguras['declividade_maxima_estatistica_percentual'] =((df_larguras.cota_maxima - df_larguras.cota_minima) / 
              (df_larguras.area / df_larguras.largura_media)) * 100

# %%
df_larguras
# Out:
#                                                geometry  largura_minima  \
# 0     POLYGON Z ((335240.868 7391047.004 0.000, 3352...       12.487652
# 1     POLYGON Z ((335207.390 7390994.550 0.000, 3352...       12.457171
# 2     POLYGON Z ((335146.804 7390957.456 0.000, 3351...       16.001422
# 3     POLYGON Z ((335005.505 7390915.742 0.000, 3349...       17.373620
# 4     POLYGON Z ((334938.200 7390852.834 0.000, 3349...       15.046812
# ...                                                 ...             ...
# 2270  POLYGON Z ((334847.946 7390752.223 0.000, 3348...             NaN
# 2271  POLYGON Z ((334844.203 7390754.734 0.000, 3348...             NaN
# 2272  POLYGON Z ((334846.486 7390761.526 0.000, 3348...             NaN
# 2273  POLYGON Z ((334846.486 7390761.526 0.000, 3348...             NaN
# 2274  POLYGON Z ((334846.436 7390761.248 0.000, 3348...             NaN
#
#       largura_maxima  largura_media  largura_desvio_padrao  \
# 0          13.191490      12.836105               0.287407
# 1          13.136217      12.732586               0.256294
# 2          20.114535      17.939740               1.404659
# 3          18.884896      18.276342               0.670159
# 4          17.032535      15.617200               0.821679
# ...              ...            ...                    ...
# 2270             NaN            NaN                    NaN
# 2271             NaN            NaN                    NaN
# 2272             NaN            NaN                    NaN
# 2273             NaN            NaN                    NaN
# 2274             NaN            NaN                    NaN
#
#       largura_contagem_amostras  cota_minima  cota_maxima  cota_media  \
# 0                             4   730.413752   731.926066  731.598856
# 1                             5   729.975883   732.232208  731.760220
# 2                            10   730.195465   732.894604  732.419005
# 3                             7   730.638656   733.942724  732.684148
# 4                             5   732.225866   734.363200  733.871905
# ...                         ...          ...          ...         ...
# 2270                          0          NaN          NaN         NaN
# 2271                          0          NaN          NaN         NaN
# 2272                          0   734.982712   734.982712  734.982712
# 2273                          0          NaN          NaN         NaN
# 2274                          0          NaN          NaN         NaN
#
#       cota_contagem_amostras  declividade_maxima_estatistica_percentual
# 0                         29                                   2.525902
# 1                         36                                   3.258984
# 2                        104                                   1.853758
# 3                         84                                   2.893771
# 4                         55                                   2.422562
# ...                      ...                                        ...
# 2270                       0                                        NaN
# 2271                       0                                        NaN
# 2272                       1                                        NaN
# 2273                       0                                        NaN
# 2274                       0                                        NaN
#
# [2275 rows x 11 columns]

# %%
df_larguras.to_file('resultado/90 - largura de vias Vila Mariana - com largura.gpkg', driver='GPKG')

# %%
# df_dists.to_file('resultado/90 - largura de vias Vila Mariana.gpkg', driver='GPKG')
