# %% [markdown]
# ## Calculando Largura de vias
#
# A intenção aqui é experimentar uma metodoloogia para se calcular a larura de vias dadas as seguintes feições:
# * Um polígono da via
# * Uma linha aproximada ao trajeto central da via
# * Poligono com as quadras adjacentes a via
#
# Para tanto disponibilizamos um arquivo que podemos acessar assim:

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_pvias = gpd.read_file("./gis/POC-largura-de-via.gpkg", layer='poligono-de-vias')

# %%
df_lvias = gpd.read_file("./gis/POC-largura-de-via.gpkg", layer='logradouros')

# %%
df_quadras = gpd.read_file("./gis/POC-largura-de-via.gpkg", layer='quadras')

# %%
f, ax = plt.subplots(1, figsize=(30,20))
df_pvias.plot(ax=ax, color="grey", alpha=0.5, linewidth=1, edgecolor='black')
df_lvias.plot(ax=ax, color="orange", lw=3)
df_quadras.plot(ax=ax, color="green", alpha=0.5, linewidth=1, edgecolor='black')

# %% [markdown]
# ## Dividir para conquistar
#
# Primeira estratégia seria dividir a linha central da via em pequenos segmentos para depois encontrar os pontos próximos nas quadras adjacentes

# %%
df_lvias.apply(lambda x: [x.geometry.length], axis=1)
# Out:
# 0     [82.84273643904555]
# 1     [80.59425436230332]
# 2     [82.95592474412558]
# 3     [83.04766092811225]
# 4    [146.85587046999353]
# 5     [56.47167724829081]
# 6     [57.98145765525419]
# dtype: object

# %% [markdown]
# Uma estratégia que pode parecer interessante seria gerar um ponto a cada 12 metros para medirmos. Isso excluiria do cálculo os segumentos de via menores que 12 metros. Esse valor pode ser reconsiderado

# %%
import math
from shapely.geometry import MultiPoint

# %%
[(((i)*12)+6+(16%12)/2) for i in range(math.floor(42/12))]
# Out:
# [8.0, 20.0, 32.0]

# %%
dist = 12.00

points = df_lvias.apply(lambda x: MultiPoint([x.geometry.interpolate(((i)*dist)+dist/2+(x.geometry.length%dist)/2) 
                                              for i in range(math.floor(x.geometry.length/dist))]), 
                        axis=1)

df_points = gpd.GeoDataFrame(geometry=points)

# %%
f, ax = plt.subplots(1, figsize=(30,20))
df_pvias.plot(ax=ax, color="grey", alpha=0.5, linewidth=1, edgecolor='black')
df_lvias.plot(ax=ax, color="orange", lw=2)
df_quadras.plot(ax=ax, color="green", alpha=0.5, linewidth=1, edgecolor='black')
df_points.plot(ax=ax, lw=4, marker='o', markersize=100, color='black')

# %% [markdown]
# Agora temos que relacionar esses pontos seu respectivo polígono de via para depois saber quais são as suas quadras adjacentes, para então medir a sua distância até elas

# %% [markdown]
# ## Relacionando o ponto ao seu polígono de via

# %%
gpd.sjoin(df_points, df_pvias, how='left', op='intersects')
# Out:
#                                             geometry  index_right
# 0  MULTIPOINT (332837.605 7391746.888, 332836.738...            0
# 1  MULTIPOINT (332841.319 7391828.522, 332840.773...            4
# 2  MULTIPOINT (332696.176 7391840.326, 332695.418...            5
# 3  MULTIPOINT (332690.929 7391757.491, 332690.171...            1
# 4  MULTIPOINT (332699.095 7391768.481, 332711.063...            3
# 5  MULTIPOINT (332848.333 7391757.553, 332860.301...            2
# 6  MULTIPOINT (332766.328 7391752.553, 332766.084...            6

# %% [markdown]
# Seria interessante talvez termos um registro para cada ponto

# %%
points = df_points.apply(lambda x: list(x.geometry.geoms), axis=1)
df_p = gpd.GeoDataFrame(geometry=[item for sublist in points for item in sublist])

# %%
df_points = gpd.sjoin(df_p, df_pvias, how='left', op='intersects', rsuffix='pvias')
df_points
# Out:
#                           geometry  index_pvias
# 0   POINT (332837.605 7391746.888)            0
# 1   POINT (332836.738 7391734.920)            0
# 2   POINT (332835.864 7391722.952)            0
# 3   POINT (332834.990 7391710.984)            0
# 4   POINT (332834.117 7391699.015)            0
# 5   POINT (332833.243 7391687.047)            0
# 6   POINT (332841.319 7391828.522)            4
# 7   POINT (332840.773 7391816.535)            4
# 8   POINT (332840.228 7391804.547)            4
# 9   POINT (332839.683 7391792.560)            4
# 10  POINT (332839.137 7391780.572)            4
# 11  POINT (332838.592 7391768.584)            4
# 12  POINT (332696.176 7391840.326)            5
# 13  POINT (332695.418 7391828.350)            5
# 14  POINT (332694.659 7391816.374)            5
# 15  POINT (332693.901 7391804.398)            5
# 16  POINT (332693.142 7391792.422)            5
# 17  POINT (332692.383 7391780.446)            5
# 18  POINT (332690.929 7391757.491)            1
# 19  POINT (332690.171 7391745.515)            1
# 20  POINT (332689.412 7391733.539)            1
# 21  POINT (332688.654 7391721.563)            1
# 22  POINT (332687.895 7391709.587)            1
# 23  POINT (332687.137 7391697.611)            1
# 24  POINT (332699.095 7391768.481)            3
# 25  POINT (332711.063 7391767.605)            3
# 26  POINT (332723.031 7391766.728)            3
# 27  POINT (332734.999 7391765.852)            3
# 28  POINT (332746.967 7391764.975)            3
# 29  POINT (332758.935 7391764.099)            3
# 30  POINT (332770.903 7391763.225)            3
# 31  POINT (332782.871 7391762.353)            3
# 32  POINT (332794.839 7391761.482)            3
# 33  POINT (332806.808 7391760.611)            3
# 34  POINT (332818.776 7391759.740)            3
# 35  POINT (332830.744 7391758.869)            3
# 36  POINT (332848.333 7391757.553)            2
# 37  POINT (332860.301 7391756.679)            2
# 38  POINT (332872.269 7391755.805)            2
# 39  POINT (332884.237 7391754.931)            2
# 40  POINT (332766.328 7391752.553)            6
# 41  POINT (332766.084 7391740.555)            6
# 42  POINT (332765.840 7391728.558)            6
# 43  POINT (332765.595 7391716.560)            6

# %% [markdown]
# ## Relacionando as quadras adjacentes ao polígono de vias
#
# Agora precisamos saber quais são as quadras adjacentes ao polígono de vias e essa é uma das vantagens de se trabalhar com um polígono e não com linhas para representar vias.

# %%
df_lvias.buffer(20, cap_style=2).plot()

# %%
df_points
# Out:
#                           geometry  index_pvias
# 0   POINT (332837.605 7391746.888)            0
# 1   POINT (332836.738 7391734.920)            0
# 2   POINT (332835.864 7391722.952)            0
# 3   POINT (332834.990 7391710.984)            0
# 4   POINT (332834.117 7391699.015)            0
# 5   POINT (332833.243 7391687.047)            0
# 6   POINT (332841.319 7391828.522)            4
# 7   POINT (332840.773 7391816.535)            4
# 8   POINT (332840.228 7391804.547)            4
# 9   POINT (332839.683 7391792.560)            4
# 10  POINT (332839.137 7391780.572)            4
# 11  POINT (332838.592 7391768.584)            4
# 12  POINT (332696.176 7391840.326)            5
# 13  POINT (332695.418 7391828.350)            5
# 14  POINT (332694.659 7391816.374)            5
# 15  POINT (332693.901 7391804.398)            5
# 16  POINT (332693.142 7391792.422)            5
# 17  POINT (332692.383 7391780.446)            5
# 18  POINT (332690.929 7391757.491)            1
# 19  POINT (332690.171 7391745.515)            1
# 20  POINT (332689.412 7391733.539)            1
# 21  POINT (332688.654 7391721.563)            1
# 22  POINT (332687.895 7391709.587)            1
# 23  POINT (332687.137 7391697.611)            1
# 24  POINT (332699.095 7391768.481)            3
# 25  POINT (332711.063 7391767.605)            3
# 26  POINT (332723.031 7391766.728)            3
# 27  POINT (332734.999 7391765.852)            3
# 28  POINT (332746.967 7391764.975)            3
# 29  POINT (332758.935 7391764.099)            3
# 30  POINT (332770.903 7391763.225)            3
# 31  POINT (332782.871 7391762.353)            3
# 32  POINT (332794.839 7391761.482)            3
# 33  POINT (332806.808 7391760.611)            3
# 34  POINT (332818.776 7391759.740)            3
# 35  POINT (332830.744 7391758.869)            3
# 36  POINT (332848.333 7391757.553)            2
# 37  POINT (332860.301 7391756.679)            2
# 38  POINT (332872.269 7391755.805)            2
# 39  POINT (332884.237 7391754.931)            2
# 40  POINT (332766.328 7391752.553)            6
# 41  POINT (332766.084 7391740.555)            6
# 42  POINT (332765.840 7391728.558)            6
# 43  POINT (332765.595 7391716.560)            6

# %%
f, ax = plt.subplots(1, figsize=(30,20))
df_pvias.plot(ax=ax, color="grey", alpha=0.5, linewidth=1, edgecolor='black')
df_lvias.plot(ax=ax, color="orange", lw=2)
df_quadras.plot(ax=ax, color="green", alpha=0.5, linewidth=1, edgecolor='black')
df_points.plot(ax=ax, lw=4, marker='o', markersize=100, color='black')

# %%
df_pvia_quadra = gpd.sjoin(df_pvias, df_quadras, how='left', op='intersects', rsuffix='quadra')
df_pvia_quadra.index.name = 'id'
df_pvia_quadra['via'] = df_pvia_quadra.index

# %%
df_pvia_quadra
# Out:
#                                              geometry  index_quadra qe_escala  \
# id
# 0   POLYGON ((332838.357 7391681.144, 332832.412 7...             2   1:1.000
# 0   POLYGON ((332838.357 7391681.144, 332832.412 7...             3   1:1.000
# 1   POLYGON ((332692.571 7391691.545, 332686.408 7...             1   1:1.000
# 1   POLYGON ((332692.571 7391691.545, 332686.408 7...             2   1:1.000
# 2   POLYGON ((332890.572 7391747.677, 332886.974 7...             3   1:1.000
# 2   POLYGON ((332890.572 7391747.677, 332886.974 7...             4   1:1.000
# 3   POLYGON ((332831.250 7391752.001, 332830.666 7...             2   1:1.000
# 3   POLYGON ((332831.250 7391752.001, 332830.666 7...             0   1:1.000
# 4   POLYGON ((332844.298 7391762.855, 332838.124 7...             0   1:1.000
# 4   POLYGON ((332844.298 7391762.855, 332838.124 7...             4   1:1.000
# 5   POLYGON ((332691.658 7391768.991, 332686.787 7...             1   1:1.000
# 5   POLYGON ((332691.658 7391768.991, 332686.787 7...             0   1:1.000
# 6   POLYGON ((332766.516 7391763.501, 332761.697 7...             2   1:1.000
#
#    qe_ano_ref  qe_area    qe_id qe_tipo  via
# id
# 0        2004   9975.0  12243.0  Quadra    0
# 0        2004   3523.0  12242.0  Quadra    0
# 1        2004  17156.0  12244.0  Quadra    1
# 1        2004   9975.0  12243.0  Quadra    1
# 2        2004   3523.0  12242.0  Quadra    2
# 2        2004   3427.0   9221.0  Quadra    2
# 3        2004   9975.0  12243.0  Quadra    3
# 3        2004   9889.0  12544.0  Quadra    3
# 4        2004   9889.0  12544.0  Quadra    4
# 4        2004   3427.0   9221.0  Quadra    4
# 5        2004  17156.0  12244.0  Quadra    5
# 5        2004   9889.0  12544.0  Quadra    5
# 6        2004   9975.0  12243.0  Quadra    6

# %%
# df_pvia_quadra_splited = gpd.overlay(gpd.GeoDataFrame(geometry=df_lvias.buffer(40, cap_style=2)), df_pvia_quadra, how='intersection')
# df_pvia_quadra_splited

# %%
gpd.sjoin(gpd.GeoDataFrame(geometry=df_pvias.geometry.buffer(1)), df_lvias, how='left', op='contains')
# Out:
#                                             geometry  index_right lg_codlog  \
# 0  POLYGON ((332830.506 7391751.334, 332830.487 7...            0    049158
# 1  POLYGON ((332693.431 7391692.056, 332693.477 7...            3    019348
# 2  POLYGON ((332844.414 7391750.565, 332844.413 7...            5    023779
# 3  POLYGON ((332697.227 7391761.038, 332697.197 7...            4    023779
# 4  POLYGON ((332835.265 7391832.394, 332835.254 7...            1    049158
# 5  POLYGON ((332689.120 7391845.030, 332689.117 7...            2    019348
# 6  POLYGON ((332767.267 7391764.161, 332772.260 7...            6      None
#
#   lg_tipo lg_titulo lg_prep   lg_nome lg_or_deno lg_ind_ofi  lg_ini_par  \
# 0       R      None    None      CHUI       None    OFICIAL       184.0
# 1       R      None    None  APENINOS       None    OFICIAL       950.0
# 2       R      None    None     ARUJA       None    OFICIAL       144.0
# 3       R      None    None     ARUJA       None    OFICIAL         0.0
# 4       R      None    None      CHUI       None    OFICIAL       106.0
# 5       R      None    None  APENINOS       None    OFICIAL       864.0
# 6    None      None    None      None       None       None         NaN
#
#    lg_fim_par  lg_ini_imp  lg_fim_imp  lg_ordem     lg_id  lg_seg_id  \
# 0       264.0       185.0       265.0       3.0   34560.0   181814.0
# 1      1030.0       951.0      1031.0      12.0   30020.0   182787.0
# 2       198.0       145.0       199.0       2.0  111716.0   181811.0
# 3       144.0         1.0       145.0       1.0  111716.0   183211.0
# 4       184.0       107.0       185.0       2.0   34560.0   183242.0
# 5       950.0       865.0       951.0      11.0   30020.0   182786.0
# 6         NaN         NaN         NaN       NaN       NaN        NaN
#
#   lg_or_geom
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None

# %%
df_lvias
# Out:
#   lg_codlog lg_tipo lg_titulo lg_prep   lg_nome lg_or_deno lg_ind_ofi  \
# 0    049158       R      None    None      CHUI       None    OFICIAL
# 1    049158       R      None    None      CHUI       None    OFICIAL
# 2    019348       R      None    None  APENINOS       None    OFICIAL
# 3    019348       R      None    None  APENINOS       None    OFICIAL
# 4    023779       R      None    None     ARUJA       None    OFICIAL
# 5    023779       R      None    None     ARUJA       None    OFICIAL
# 6      None    None      None    None      None       None       None
#
#    lg_ini_par  lg_fim_par  lg_ini_imp  lg_fim_imp  lg_ordem     lg_id  \
# 0       184.0       264.0       185.0       265.0       3.0   34560.0
# 1       106.0       184.0       107.0       185.0       2.0   34560.0
# 2       864.0       950.0       865.0       951.0      11.0   30020.0
# 3       950.0      1030.0       951.0      1031.0      12.0   30020.0
# 4         0.0       144.0         1.0       145.0       1.0  111716.0
# 5       144.0       198.0       145.0       199.0       2.0  111716.0
# 6         NaN         NaN         NaN         NaN       NaN       NaN
#
#    lg_seg_id lg_or_geom                                           geometry
# 0   181814.0       None  MULTILINESTRING ((332838.124 7391758.298, 3328...
# 1   183242.0       None  MULTILINESTRING ((332841.787 7391838.809, 3328...
# 2   182786.0       None  MULTILINESTRING ((332696.902 7391851.781, 3326...
# 3   182787.0       None  MULTILINESTRING ((332691.658 7391768.991, 3326...
# 4   183211.0       None  MULTILINESTRING ((332691.687 7391769.023, 3327...
# 5   181811.0       None  MULTILINESTRING ((332838.124 7391758.298, 3328...
# 6        NaN       None  MULTILINESTRING ((332766.552 7391763.541, 3327...

# %% [markdown]
# Agora podemos relacionar os pontos ao DataFrame de poligonos de vias e quadras que acabamos de criar

# %% [markdown]
# ## Calculando as distâncias
#
# Agora podemos a partir de cada ponto, calcular a distância para cada quadra adjacente ao seu respectivo polígono de via.
#
# Na maioria dos casos vamos ter apenas duas quadras adjacentes, mas é possível acontecer casos em que há apenas uma e mais do que duas.
#
# Nos casos onde só exista uma quadra adjacente podemos desconsiderar o cálculo.
#
# Nos casos onde ocorrerem mais do que duas quadras adjacentes, vamos utilizar as duas medidas mais próximas, o que faz sentido, uma vez que buscamos a largura mínima da via.

# %%
from shapely.ops import nearest_points
from shapely.geometry import LineString, MultiPoint
from shapely.ops import split

# %%
# def calc_distancia(p):
#     quadras = list(df_pvia_quadra[df_pvia_quadra.index == p.index_pvias].index_quadra)
#     quadras = df_quadras[df_quadras.index.isin(quadras)]
#     pontos  = []
    
#     for i, row in quadras.iterrows():
#         pontos.append(nearest_points(p.geometry, row.geometry)[1])
        
#     return LineString(pontos)

# df_dists = gpd.GeoDataFrame(geometry=df_points.apply(lambda x: calc_distancia(x), axis=1))

# %%
def calc_distancia(p):
    quadras = list(df_pvia_quadra[df_pvia_quadra.via == p.index_pvias].index_quadra)
    quadras = df_quadras[df_quadras.index.isin(quadras)]
    pontos  = []
    
    for i, row in quadras.iterrows():
        pontos.append(nearest_points(p.geometry, row.geometry)[1])
    
    if len(pontos) == 2:   
        return LineString(pontos)
    elif len(pontos) > 2:  
        bd = split(MultiPoint(pontos).convex_hull.boundary, MultiPoint(pontos))
        return min(bd, key=(lambda x: x.length))
    else:
        return None
    

# df_dists = gpd.GeoDataFrame(geometry=df_points.apply(lambda x: calc_distancia(x), axis=1))
df_dists = gpd.GeoDataFrame(geometry=df_points.apply(lambda x: calc_distancia(x), axis=1))

# %%
df_dists = df_dists[~df_dists.is_empty]

# %%
import numpy as np
f, ax = plt.subplots(1, figsize=(30,20))
df_pvias.plot(ax=ax, color="grey", alpha=0.5, linewidth=1, edgecolor='black')
df_lvias.plot(ax=ax, color="orange", lw=2)
df_quadras.plot(ax=ax, color="green", alpha=0.5, linewidth=1, edgecolor='black')

c = np.random.rand(len(df_dists), 3)

df_dists.plot(ax=ax,lw=4, color=c)
df_points.plot(ax=ax, lw=4, marker='x', markersize=100, color=c)

# %%
# df_dists.length
